# %% [markdown]
# <a href="https://colab.research.google.com/github/TiaErikaDev/ExerciciosDataAnalytics/blob/main/Data_Analytics_Aula_10_Matplotlib_Elei%C3%A7%C3%B5es.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget https://raw.githubusercontent.com/jonates/opendata/master/eleicoes_2018/resultados_candidato_2018.csv
# Out:
# --2022-08-11 00:18:01--  https://raw.githubusercontent.com/jonates/opendata/master/eleicoes_2018/resultados_candidato_2018.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2851282 (2.7M) [text/plain]
# Saving to: ‘resultados_candidato_2018.csv.2’
#
# resultados_candidat 100%[===================>]   2.72M  --.-KB/s    in 0.05s
#
# 2022-08-11 00:18:01 (58.2 MB/s) - ‘resultados_candidato_2018.csv.2’ saved [2851282/2851282]

# %%
# !wget https://raw.githubusercontent.com/jonates/opendata/master/eleicoes_2018/candidatos_2018.csv
# Out:
# --2022-08-11 00:18:02--  https://raw.githubusercontent.com/jonates/opendata/master/eleicoes_2018/candidatos_2018.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 9506208 (9.1M) [text/plain]
# Saving to: ‘candidatos_2018.csv.2’
#
# candidatos_2018.csv 100%[===================>]   9.07M  --.-KB/s    in 0.07s
#
# 2022-08-11 00:18:02 (128 MB/s) - ‘candidatos_2018.csv.2’ saved [9506208/9506208]

# %%
import pandas as pd

# %%
resultados = pd.read_csv(
    filepath_or_buffer = 'https://raw.githubusercontent.com/jonates/opendata/master/eleicoes_2018/resultados_candidato_2018.csv',
    sep = ';',
    decimal = ',',
    encoding = 'latin-1'
)

# %%
resultados.head(5)
# Out:
#     ano  turno       tipo_eleicao sigla_uf  id_municipio  id_municipio_tse  \
# 0  2018      1  eleicao ordinaria      NaN           NaN               NaN
# 1  2018      1  eleicao ordinaria      NaN           NaN               NaN
# 2  2018      1  eleicao ordinaria      NaN           NaN               NaN
# 3  2018      1  eleicao ordinaria      NaN           NaN               NaN
# 4  2018      1  eleicao ordinaria      NaN           NaN               NaN
#
#         cargo sigla_partido  numero_candidato  sequencial_candidato  \
# 0  presidente            DC                27          280000624085
# 1  presidente           MDB                15          280000622281
# 2  presidente          NOVO                30          280000607640
# 3  presidente      PATRIOTA                51          280000602500
# 4  presidente           PDT                12          280000605589
#
#    id_candidato_bd   resultado     votos
# 0              NaN  nao eleito     41710
# ...

# %%
candidatos = pd.read_csv(
    filepath_or_buffer = 'candidatos_2018.csv',
    sep = ';',
    decimal = ',',
    encoding = 'latin-1'
)

# %%
candidatos.head(5)
# Out:
#     ano       tipo_eleicao sigla_uf  id_municipio  id_municipio_tse  \
# 0  2018  eleicao ordinaria       CE           NaN               NaN
# 1  2018  eleicao ordinaria       MG           NaN               NaN
# 2  2018  eleicao ordinaria       RJ           NaN               NaN
# 3  2018  eleicao ordinaria       RR           NaN               NaN
# 4  2018  eleicao ordinaria       MG           NaN               NaN
#
#    id_candidato_bd          cpf  titulo_eleitoral    sequencial  numero  ...  \
# 0             37.0  32598190378       10180710701   60000620569   50200  ...
# 1             47.0  32598769600       72144590299  130000606560   70456  ...
# 2             72.0  01344807755       75556700370  190000606091    3121  ...
# 3            150.0  01344895271        4176482607  230000602217   36490  ...
# 4            162.0  32604335620        7589471368  130000629811      18  ...
#
#   data_nascimento idade     genero                 instrucao estado_civil  \
# ...

# %%
resultados.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26462 entries, 0 to 26461
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ano                   26462 non-null  int64
#  1   turno                 26462 non-null  int64
#  2   tipo_eleicao          26462 non-null  object
#  3   sigla_uf              26447 non-null  object
#  4   id_municipio          0 non-null      float64
#  5   id_municipio_tse      0 non-null      float64
#  6   cargo                 26462 non-null  object
#  7   sigla_partido         26462 non-null  object
#  8   numero_candidato      26462 non-null  int64
#  9   sequencial_candidato  26462 non-null  int64
#  10  id_candidato_bd       26386 non-null  float64
#  11  resultado             26462 non-null  object
#  12  votos                 26462 non-null  int64
# dtypes: float64(3), int64(5), object(5)
# memory usage: 2.6+ MB

# %%
candidatos.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28972 entries, 0 to 28971
# Data columns (total 27 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ano                   28972 non-null  int64
#  1   tipo_eleicao          28972 non-null  object
#  2   sigla_uf              28945 non-null  object
#  3   id_municipio          0 non-null      float64
#  4   id_municipio_tse      0 non-null      float64
#  5   id_candidato_bd       28914 non-null  float64
#  6   cpf                   28972 non-null  object
#  7   titulo_eleitoral      28972 non-null  int64
#  8   sequencial            28972 non-null  int64
#  9   numero                28972 non-null  int64
#  10  nome                  28972 non-null  object
#  11  nome_urna             28972 non-null  object
#  12  numero_partido        28972 non-null  int64
#  13  sigla_partido         28972 non-null  object
#  14  cargo                 28972 non-null  object
# ...

# %%
#filtrando apenas algumas informações
candidatos_para_merge = candidatos[['sequencial', 'nome', 'nome_urna', 'numero_partido',\
                                    'situacao', 'ocupacao', 'genero', 'idade', 'instrucao', 'estado_civil',\
                                    'nacionalidade', 'sigla_uf_nascimento', 'municipio_nascimento',\
                                    'raca']]

# %%
#Juntando as bases de dados
eleicoes = pd.merge(
    left = resultados,
    right = candidatos_para_merge,
    how = 'left',
    left_on = 'sequencial_candidato',
    right_on = 'sequencial'
)

# %%
eleicoes.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 26462 entries, 0 to 26461
# Data columns (total 27 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ano                   26462 non-null  int64
#  1   turno                 26462 non-null  int64
#  2   tipo_eleicao          26462 non-null  object
#  3   sigla_uf              26447 non-null  object
#  4   id_municipio          0 non-null      float64
#  5   id_municipio_tse      0 non-null      float64
#  6   cargo                 26462 non-null  object
#  7   sigla_partido         26462 non-null  object
#  8   numero_candidato      26462 non-null  int64
#  9   sequencial_candidato  26462 non-null  int64
#  10  id_candidato_bd       26386 non-null  float64
#  11  resultado             26462 non-null  object
#  12  votos                 26462 non-null  int64
#  13  sequencial            26452 non-null  float64
#  14  nome                  26452 non-null  object
# ...

# %%
eleicoes
# Out:
#         ano  turno       tipo_eleicao sigla_uf  id_municipio  \
# 0      2018      1  eleicao ordinaria      NaN           NaN
# 1      2018      1  eleicao ordinaria      NaN           NaN
# 2      2018      1  eleicao ordinaria      NaN           NaN
# 3      2018      1  eleicao ordinaria      NaN           NaN
# 4      2018      1  eleicao ordinaria      NaN           NaN
# ...     ...    ...                ...      ...           ...
# 26457  2018      2  eleicao ordinaria       SC           NaN
# 26458  2018      2  eleicao ordinaria       SE           NaN
# 26459  2018      2  eleicao ordinaria       SE           NaN
# 26460  2018      2  eleicao ordinaria       SP           NaN
# 26461  2018      2  eleicao ordinaria       SP           NaN
#
#        id_municipio_tse       cargo sigla_partido  numero_candidato  \
# 0                   NaN  presidente            DC                27
# 1                   NaN  presidente           MDB                15
# ...

# %%
#importando as bibliotecas necessárias
import matplotlib.pyplot as plt

# %%
#Distribuição por sexo
perfil_sexo = eleicoes.genero.value_counts()\
    .rename_axis('sexo') \
    .to_frame('candidatos') \
    .reset_index()

perfil_sexo
# Out:
#         sexo  candidatos
# 0  masculino       18226
# 1   feminino        8225

# %%
plt.pie(x=perfil_sexo.candidatos, labels=perfil_sexo.sexo);

# %%
#Inserir as porcentagens
plt.pie(x=perfil_sexo.candidatos, labels=perfil_sexo.sexo, autopct = '%.2f%%');

# %%
#Customizando o gráfico
plt.pie(
    x=perfil_sexo.candidatos, 
    labels=perfil_sexo.sexo, 
    autopct = '%.2f%%',
    shadow = True,
    colors = ['blue', 'magenta'],
    explode = [0,0.1],
    startangle = 90,
    textprops = dict(color='white')
    );
